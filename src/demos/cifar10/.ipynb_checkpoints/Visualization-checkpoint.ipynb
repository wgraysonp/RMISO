# %%
import os
#%matplotlib notebook
import matplotlib.pyplot as plt
import torch
import numpy as np
from PIL import Image

plt.rcParams.update({
    "font.family": "serif",  # use serif/main font for text elements
    #"font.size"   : 15,
    "text.usetex": True,  # use inline math for ticks
    "pgf.rcfonts": False,  # don't setup fonts from rc parameters
    "pgf.preamble": "\n".join([
        "\\usepackage{units}",  # load additional packages
        "\\usepackage{metalogo}",
        "\\usepackage{unicode-math}",  # unicode math setup
        r"\setmathfont{xits-math.otf}",
        r"\setmainfont{DejaVu Serif}",  # serif font via preamble
    ])
})

LABELS = ["sgd", "rmiso", "adam", "mcsag"]

# %%
def get_folder_path(use_pretrained=True):
    path = 'curve'
    if use_pretrained:
        path = os.path.join(path, 'pretrained')
    return path

# %%
def get_curve_data(use_pretrained=True, model='one_layer'):
    folder_path = get_folder_path(use_pretrained)
    filenames = [name for name in os.listdir(folder_path) if name.startswith(model.lower())]
    paths = [os.path.join(folder_path, name) for name in filenames]
    optims = [name.split('-')[1] for name in filenames]
    lrs = [float(name.split('-')[2][2:]) for name in filenames]
    algs = [name.split('-')[-1] for name in filenames]
    nodes = [int(name.split('-')[-4][6:]) for name in filenames]
    edges = [int(name.split('-')[-3][6:]) for name in filenames]
    hyperparams = [name.split('-')[3:-4] for name in filenames]
    return [{"optim": op, "lr": l, "alg": alg, "hyp_params": hp, "nodes": nodes, "edges": edges, "curve": torch.load(fp)}
            for op, l, alg, hp, nodes, edges, fp in zip(optims, lrs, algs, hyperparams, nodes, edges, paths)]

# %%
def plot(use_pretrained=True, model='one_layer', optimizers=None, title=None, ylim=(60, 80), curve_type='train', algorithm='uniform'):
    assert model in ['one_layer', 'two_layer'], 'Invalid model name: {}'.format(model)
    assert curve_type in ['train_acc', 'test_acc', 'train_loss', 'test_loss'], 'Invalid curve type: {}'.format(curve_type)
    assert all(_ in LABELS for _ in optimizers), 'Invalid optimizer'
    
    curve_data = get_curve_data(use_pretrained, model=model)
    
    plt.figure()
    if curve_type.split("_")[1] == "acc":
        if title is None:
            title = '{} Accurcy for {} on covertype'.format(curve_type.split("_")[0].capitalize(), model)
        plt.ylabel('{} Accuracy %'.format(curve_type.split("_")[0].capitalize()))
    else:
        if title is None:
            title = '{} Loss for {} on covertype'.format(curve_type.split("_")[0].capitalize(), model)
        plt.ylabel('{} Loss'.format(curve_type.split("_")[0].capitalize()))

    plt.title(title)
    plt.xlabel('Epoch')
    plt.xlim(0, 100)
    plt.ylim(ylim)
    
    for curve in curve_data:
        optim = curve['optim']
        lr = curve['lr']
        alg = curve['alg']
        linestyle = '-' if 'rmiso' in optim else '-'
        marker = 'o' if 'rmiso' in optim else ''
        if 'SMM' in optim:
            marker = '*'
        
        if optim in optimizers.keys() and lr in optimizers[optim] and alg == algorithm:
            accuracies = np.array(curve['curve'][curve_type])
            if optim == "rmiso":
                initial_lr = None
                final_lr = None
                try:
                    initial_lr = curve['hyp_params'][2][10:]
                    final_lr = curve['hyp_params'][3][8:]
                except IndexError:
                    pass
                delta = curve['hyp_params'][1][5:]
                rho = curve['hyp_params'][0][3:]
                if initial_lr is not None and initial_lr != final_lr:
                    label = "RMISO-inital_lr: {:.0f} -final_lr: {:.0f} -rho {:.0e} -delta: {:.0e}".format(float(initial_lr), float(final_lr), float(rho), float(delta))
                else:
                    label = "RMISO-lr: {} - rho - {:.0e} - delta: {:.0e}".format(lr, float(rho), float(delta))
            elif optim == "sgd":
                label = "SGD-HB-lr: {}".format(lr)
            elif optim =="mcsag" and alg == 'uniform':
                label = "SAG-lr: {}".format(lr)
            else:
                label = f"{optim.upper()}-lr {lr}" 
            plt.plot(accuracies, label=label, ls=linestyle, marker=marker, markevery=5)
        

        
    plt.grid(ls='--')
    plt.legend(ncol=2)
    plt.show()
    save_name = "{}_{}".format(model, curve_type)+".pdf" 
    #plt.savefig(save_name, bbox_inches="tight")

# %% [markdown]
# ## One Layer Model - Uniform

# %%
title_train = "Comparison of RMISO learning rates for One Layer on Covertype: Train Uniform"
title_test = "Comparison of RMISO learning rates for One Layer on Covertype: Test Uniform"
plot(use_pretrained=False, model='one_layer', 
     title=title_train, optimizers={"rmiso": [20, 10, 5, 1]}, curve_type='train_acc')
plot(use_pretrained=False, model='one_layer',
     title=title_test, optimizers={"rmiso": [20, 10, 5, 1]}, curve_type='test_acc')

# %%
plot(use_pretrained=False, model='one_layer', 
     title=title_train, optimizers={"rmiso": [20, 10, 5, 1]}, ylim=(0.15, 0.22), curve_type='train_loss')
plot(use_pretrained=False, model='one_layer',
     title=title_test, optimizers={"rmiso": [20, 10, 5, 1]}, ylim=(0.15, 0.22), curve_type='test_loss')

# %%
optimizers = {"rmiso": [20.0], "mcsag": [10.0], "sgd": [0.1], "adam": [0.01]}

plot(use_pretrained=False, model='one_layer', 
     title=None, optimizers=optimizers, curve_type='train_acc', ylim=(75, 77.5))
plot(use_pretrained=False, model='one_layer',
     title=None, optimizers=optimizers, curve_type='test_acc', ylim=(75, 77.5))

# %% [markdown]
# ## One Layer Model - MCMC

# %%
title_train = "Comparison of RMISO learning rates for One Layer on Covertype: MCMC"
title_test = "Comparison of RMISO learning rates for One Layer on Covertype: MCMC"
plot(use_pretrained=False, model='one_layer', 
     title=title_train, optimizers={"rmiso": [20, 10, 5, 1]}, curve_type='train_acc', algorithm="metropolis_hastings")
plot(use_pretrained=False, model='one_layer',
     title=title_test, optimizers={"rmiso": [20, 10, 5, 1]}, curve_type='test_acc', algorithm="metropolis_hastings")

# %%
plot(use_pretrained=False, model='one_layer',
     title=title_test, optimizers={"rmiso": [20, 10, 5, 1]}, ylim=(0.15, 0.3), curve_type='train_loss', algorithm="metropolis_hastings")
plot(use_pretrained=False, model='one_layer',
     title=title_test, optimizers={"rmiso": [20, 10, 5, 1]}, ylim=(0.15, 0.3), curve_type='test_loss', algorithm="metropolis_hastings")

# %%
optimizers = {"rmiso": [20.0], "mcsag": [10.0], "sgd": [0.1], "adam": [0.01]}

plot(use_pretrained=False, model='one_layer', 
     title=None, optimizers=optimizers, curve_type='train_acc', ylim=(72.5, 77.6), algorithm="metropolis_hastings")
plot(use_pretrained=False, model='one_layer',
     title=None, optimizers=optimizers, curve_type='test_acc', ylim=(72.5, 77.6), algorithm="metropolis_hastings")

# %% [markdown]
# ## Two Layer Model -Uniform

# %%
title_train = "Comparison of RMISO learning rates for Two Layer on Covertype: Uniform"
title_test = "Comparison of RMISO learning rates for Two Layer on Covertype: Uniform"
plot(use_pretrained=False, model='two_layer', 
     title=title_train, optimizers={"rmiso": [20, 10, 5, 1]}, ylim=(65, 83), curve_type='train_acc', algorithm="uniform")
plot(use_pretrained=False, model='two_layer',
     title=title_test, optimizers={"rmiso": [20, 10, 5, 1]}, ylim=(65, 83), curve_type='test_acc', algorithm="uniform")

# %%
plot(use_pretrained=False, model='two_layer',
     title=title_test, optimizers={"rmiso": [500, 20, 10, 5, 1]}, ylim=(0.45, 0.7), curve_type='train_loss', algorithm="uniform")
plot(use_pretrained=False, model='two_layer',
     title=title_test, optimizers={"rmiso": [500, 20, 10, 5, 1]}, ylim=(0.45, 0.7), curve_type='test_loss', algorithm="uniform")

# %%
optimizers = {"rmiso": [500, 20], "mcsag": [10.0], "sgd": [1], "adam": [0.01]}

plot(use_pretrained=False, model='two_layer', 
     title=None, optimizers=optimizers, curve_type='train_acc', ylim=(72.5, 83), algorithm="uniform")
plot(use_pretrained=False, model='two_layer',
     title=None, optimizers=optimizers, curve_type='test_acc', ylim=(72.5, 83), algorithm="uniform")

# %% [markdown]
# ## Two-Layer Model -MCMC

# %%
title_train = "Comparison of RMISO learning rates for Two Layer on Covertype: MCMC"
title_test = "Comparison of RMISO learning rates for Two Layer on Covertype: MCMC"
plot(use_pretrained=False, model='two_layer', 
     title=title_train, optimizers={"rmiso": [500, 20, 10, 5, 1]}, ylim=(65, 83), curve_type='train_acc', algorithm="metropolis_hastings")
plot(use_pretrained=False, model='two_layer',
     title=title_test, optimizers={"rmiso": [500, 20, 10, 5, 1]}, ylim=(65, 83), curve_type='test_acc', algorithm="metropolis_hastings")

# %%
plot(use_pretrained=False, model='two_layer',
     title=title_test, optimizers={"rmiso": [500, 20, 10, 5, 1]}, ylim=(0.45, 0.7), curve_type='train_loss', algorithm="metropolis_hastings")
plot(use_pretrained=False, model='two_layer',
     title=title_test, optimizers={"rmiso": [500, 20, 10, 5, 1]}, ylim=(0.45, 0.7), curve_type='test_loss', algorithm="metropolis_hastings")

# %%
optimizers = {"rmiso": [ 500, 20.0, 10], "mcsag": [10.0], "sgd": [1], "adam": [0.01]}

plot(use_pretrained=False, model='two_layer', 
     title=None, optimizers=optimizers, curve_type='train_acc', ylim=(65, 83), algorithm="metropolis_hastings")
plot(use_pretrained=False, model='two_layer',
     title=None, optimizers=optimizers, curve_type='test_acc', ylim=(65, 83), algorithm="metropolis_hastings")

# %%
img = Image.open("saved_graphs/graph_pics/alg:uniform-nodes:100-edges:500.jpg")
plt.imshow(img)
